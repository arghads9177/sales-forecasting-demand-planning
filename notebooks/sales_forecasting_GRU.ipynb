# %% [markdown]
# # Sales Analysis, Forecasting and Demand Planning Project
#
# ## Project Overview
# This project focuses on developing a robust sales forecasting and demand planning system for retail businesses. By analyzing historical sales data, we aim to optimize production, inventory management, and resource planning by accurately predicting future sales trends. Leveraging machine learning and statistical models, this project provides actionable insights to improve operational efficiency, reduce costs, and enhance customer satisfaction.
#
# ---
#
# ## About the Dataset
#
# This dataset provides historical sales data for the retail furniture sector, serving as a valuable resource for business analysis. It includes detailed transaction-level information that can be used to understand sales trends, forecast future demand, and optimize inventory. The dataset enables informed decision-making to ensure business stability and growth in the competitive retail environment.
#
# ## Data Source
#
# This sales data is available on Kaggle in the following Link,
#
# > https://www.kaggle.com/datasets/tanayatipre/store-sales-forecasting-dataset
#
# ### Dataset Features
#
# | Feature          | Description                                                                          |
# |-------------------|--------------------------------------------------------------------------------------|
# | `Row ID`         | Sequential identifier for each row.                                                 |
# | `Order ID`       | Unique identifier for each sales order.                                             |
# | `Order Date`     | Date of the sales order.                                                            |
# | `Ship Date`      | Date of shipment for the order.                                                     |
# | `Ship Mode`      | Mode of shipment for the order.                                                     |
# | `Customer ID`    | Unique identifier for each customer.                                                |
# | `Customer Name`  | Name of the customer.                                                               |
# | `Segment`        | Segment classification of the customer.                                             |
# | `Country`        | Country where the sale occurred.                                                    |
# | `City`           | City where the sale occurred.                                                       |
# | `State`          | State where the sale occurred.                                                      |
# | `Postal Code`    | Postal code where the sale occurred.                                                |
# | `Region`         | Geographical region where the sale occurred.                                        |
# | `Product ID`     | Unique identifier for each product.                                                 |
# | `Category`       | Category classification of the product.                                             |
# | `Sub-Category`   | Sub-category classification of the product.                                         |
# | `Product Name`   | Name of the product.                                                                |
# | `Sales`          | Total sales amount for the order.                                                   |
# | `Quantity`       | Quantity of products sold in the order.                                             |
# | `Discount`       | Discount applied to the order.                                                      |
# | `Profit`         | Profit generated from the order.                                                    |
#
# ---
#
# ## Business Objectives
#
# 1. **Sales Forecasting:**
#    - Predict sales for the next 30 days for each product category.
#    - Identify and leverage trends and seasonality in sales patterns.
#
# 2. **Demand Planning:**
#    - Determine products or categories likely to experience surges in demand.
#    - Reduce overstocking and understocking through accurate forecasts.
#
# 3. **Optimization:**
#    - Optimize production schedules and inventory management.
#    - Identify periods requiring special promotions to counter seasonal declines.
#
# ---
#
# ## Methodology
#
# ### 1. **Data Understanding**
#    - **Data Collection:** Gather historical sales data, pricing, promotions, holidays, and external factors (e.g., weather).
#    - **Exploratory Data Analysis (EDA):** Perform statistical analysis and create visualizations to uncover trends, seasonality, and anomalies.
#    - **Data Quality Assessment:** Identify and address missing, inconsistent, or irrelevant data.
#
# ### 2. **Data Preparation**
#    - **Data Cleaning:** Handle missing values, outliers, and duplicates. Normalize sales data if necessary.
#    - **Feature Engineering:** Create lag variables, rolling averages, seasonal indices, and encode categorical variables for modeling.
#    - **Data Splitting:** Split the dataset into training, validation, and testing sets.
#
# ### 3. **Modeling**
#    - **Baseline Models:** Develop simple models such as moving averages or exponential smoothing for benchmarking.
#    - **Advanced Models:** Train machine learning (e.g., ARIMA, SARIMA, XGBoost, Random Forest) and deep learning models (e.g., LSTM, GRU, Prophet).
#    - **Hyperparameter Optimization:** Fine-tune models to enhance accuracy and efficiency.
#
# ### 4. **Evaluation**
#    - **Evaluation Metrics:** Use RMSE, MAPE, MAE, and R² to assess model performance.
#    - **Visualization:** Plot predicted vs. actual sales to analyze trends and deviations.
#    - **Model Selection:** Choose the best-performing model for deployment.
#
# ---
#
# ## Applications
#
# - **Inventory Management:** Ensure optimal inventory levels, minimizing costs associated with overstocking or stockouts.
# - **Production Planning:** Use forecasts to adjust production schedules based on predicted demand.
# - **Promotional Campaigns:** Identify low-demand periods and design targeted promotions to boost sales.
# - **Revenue Forecasting:** Provide accurate revenue projections to guide financial planning.
#
# ---
#
# ## Research Questions
#
# 1. What are the expected sales for the next 30 days for each product category?
# 2. Which products or categories show clear trends or seasonal demand patterns?
# 3. How can accurate demand forecasts improve inventory management and reduce operational costs?
# 4. Which time periods require targeted promotional strategies to mitigate sales dips?
#
# ---
#
# ## Results and Insights
#
# 1. **Seasonal Trends:** Sales demonstrate clear peaks during holiday seasons and dips during specific months.
# 2. **Top-Selling Products:** Analysis of product categories reveals best-performing items and their contribution to revenue.
# 3. **Demand Surges:** Certain products experience predictable spikes in demand, enabling proactive inventory management.
# 4. **Model Performance:** LSTM and SARIMA models outperformed baseline methods in forecasting accuracy.
#
# ---
#
# ## Conclusion
#
# This project equips retail businesses with powerful forecasting tools to make data-driven decisions. By understanding historical sales patterns, businesses can optimize inventory, enhance production efficiency, and maximize profitability while maintaining customer satisfaction.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout, GRU
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
# Out:
# 2024-12-06 08:02:36.451168: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Settings

# %%
# Warnings
warnings.filterwarnings("ignore")

# Plot
sns.set_style("darkgrid")

# Path
data_path = "../data"
model_path = "../models"
# csv_path = os.path.join(data_path, "ssf_monthly.csv")
csv_path = os.path.join(data_path, "ssf_cleaned.csv")

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv(csv_path)

# %%
# Check Data
df.head()
# Out:
#          Date        Sales
# 0  2014-01-06  2573.820000
# 1  2014-01-07    76.728000
# 2  2014-01-08    68.465333
# 3  2014-01-09    60.202667
# 4  2014-01-10    51.940000

# %% [markdown]
# ### Define Functions for Data Preprocessing, Model Preparation, Training and Evaluation

# %%
# Data Preparation

def prepare_data(data, feature):
    data = data[feature].values.reshape(-1, 1)
    sc = MinMaxScaler(feature_range= (0,1))
    data_scaled = sc.fit_transform(data)
    return data_scaled, sc

# Create sequences
def create_sequence(data, time_steps= 10):
    X, y = [], []
    for i in range(time_steps, len(data)):
        X.append(data[i - time_steps:i, 0])  # Sequence of time_steps
        y.append(data[i, 0])   # Next value after the sequence
    return np.array(X), np.array(y)

# Split the data in train and test set
def train_test_split(X, y, train_split_at= 0.8):
    train_size = int(len(X) * train_split_at)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    return X_train, X_test, y_train, y_test

# Build and compile model
def build_compile_lstm(X):
    # Initialize model
    model = Sequential([
        Input(shape= (X.shape[1], 1)), # Input Layer
        GRU(50, return_sequences= True), # Hidden GRU Layer 1
        Dropout(0.2), # Dropout layer 1
        GRU(50, return_sequences= True), # Hidden GRU Layer 2
        Dropout(0.2), # Dropout layer 2
        GRU(50, return_sequences= True), # Hidden GRU Layer 3
        Dropout(0.2), # Dropout Layer 3
        Dense(1) # Output Layer
    ])
    # Compile the model
    model.compile(optimizer="adam", loss= "mean_squared_error")
    return model

# Train Model
def train_model(model, X_train, y_train, X_test, y_test, epochs= 50, batch_size= 16):
    # Train the model
    model.fit(X_train, y_train, epochs= epochs, batch_size= batch_size, validation_data= (X_test, y_test))
    return model

# Evaluate model
def evaluate_model(model, sc, X_train, y_train, X_test, y_test):
    # Make Predictions on train
    y_pred = model.predict(X_train)
    # print("Scaler input features:", sc.n_features_in_)
    # print("y_pred shape:", y_pred.shape)
    # print("y_test shape:", y_test.shape)
    y_pred_last = y_pred[:, -1, :] # Extract the last shape
    # print("y_pred_2d shape:", y_pred_last.shape)
    y_pred = sc.inverse_transform(y_pred_last)
    y_train = y_train.reshape(-1, 1)  # Shape: (num_samples, 1)
    y_train = sc.inverse_transform(y_train)

    # Filter out the small values to avoid division by small values
    threshold= 1
    valid_indices = y_train > threshold
    y_train_filtered= y_train[valid_indices]
    y_pred_last_filtered = y_pred_last[valid_indices]

    # Evaluate the model
    rmse = np.sqrt(mean_squared_error(y_train_filtered, y_pred_last_filtered))
    mape = mean_absolute_percentage_error(y_train_filtered, y_pred_last_filtered)
    mae = mean_absolute_error(y_train_filtered, y_pred_last_filtered)
    # score = r2_score(y_train_filtered, y_pred_last_filtered)
    # Print metrics
    print(f"RMSE: {rmse: 0.4f}")
    print(f"MAPE: {mape * 100: 0.2f}")
    print(f"MAE: {mae: 0.4f}")
    # print(f"Score: {score: 0.2f}")
    # Make Predictions on test
    y_pred = model.predict(X_test)
    # print("Scaler input features:", sc.n_features_in_)
    # print("y_pred shape:", y_pred.shape)
    # print("y_test shape:", y_test.shape)
    y_pred_last = y_pred[:, -1, :] # Extract the last shape
    # print("y_pred_2d shape:", y_pred_last.shape)
    y_pred = sc.inverse_transform(y_pred_last)
    y_test = y_test.reshape(-1, 1)  # Shape: (num_samples, 1)
    y_test = sc.inverse_transform(y_test)

    # Filter out the small values to avoid division by small values
    threshold= 1
    valid_indices = y_test > threshold
    y_test_filtered= y_test[valid_indices]
    y_pred_last_filtered = y_pred_last[valid_indices]

    # Evaluate the model
    rmse = np.sqrt(mean_squared_error(y_test_filtered, y_pred_last_filtered))
    mape = mean_absolute_percentage_error(y_test_filtered, y_pred_last_filtered)
    mae = mean_absolute_error(y_test_filtered, y_pred_last_filtered)
    # score = r2_score(y_test_filtered, y_pred_last_filtered)
    # Print metrics
    print(f"RMSE: {rmse: 0.4f}")
    print(f"MAPE: {mape * 100: 0.2f}")
    print(f"MAE: {mae: 0.4f}")

# %% [markdown]
# ### Data Preprocessing

# %%
data, scaler = prepare_data(df, "Sales")

# %%
# Create Data sequence
X, y = create_sequence(data, 5)
# Sanity check
print(f"Shape of X: {X.shape}") # Expected: (num_samples, time_steps, num_features)
print(f"Shape of y: {y.shape}") # Expexted(num_samples, num_features)
# Out:
# Shape of X: (1450, 5)
# Shape of y: (1450,)

# %%
# Split the data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y)
# Sanity check
print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of X_train: (1160, 5)
# Shape of y_train: (1160,)
# Shape of X_test: (290, 5)
# Shape of y_test: (290,)

# %% [markdown]
# ### Model Training and Evaluation

# %%
# Build the model
model = build_compile_lstm(X_train)

# Print model summary
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_9 (GRU)                     │ (None, 5, 50)          │         7,950 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 5, 50)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_10 (GRU)                    │ (None, 5, 50)          │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 5, 50)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_11 (GRU)                    │ (None, 5, 50)          │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 5, 50)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 5, 1)           │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,601 (150.79 KB)
#  Trainable params: 38,601 (150.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
model = train_model(model, X_train, y_train, X_test, y_test, epochs = 500, batch_size= 4)
# Out:
# Epoch 1/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 2/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0080 - val_loss: 0.0093
# Epoch 3/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0098 - val_loss: 0.0094
# Epoch 4/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0086 - val_loss: 0.0094
# Epoch 5/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 6/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0069 - val_loss: 0.0090
# Epoch 7/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0089 - val_loss: 0.0089
# Epoch 8/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0084 - val_loss: 0.0093
# Epoch 9/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0063 - val_loss: 0.0094
# Epoch 10/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 11/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 12/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0089 - val_loss: 0.0089
# Epoch 13/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 14/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0083 - val_loss: 0.0090
# Epoch 15/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0075 - val_loss: 0.0094
# Epoch 16/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0067 - val_loss: 0.0091
# Epoch 17/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0092 - val_loss: 0.0091
# Epoch 18/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0081 - val_loss: 0.0094
# Epoch 19/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 20/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0083 - val_loss: 0.0091
# Epoch 21/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 22/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0086 - val_loss: 0.0090
# Epoch 23/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0079 - val_loss: 0.0090
# Epoch 24/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 25/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 26/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 27/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 28/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0085 - val_loss: 0.0095
# Epoch 29/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0071 - val_loss: 0.0092
# Epoch 30/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0056 - val_loss: 0.0090
# Epoch 31/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0096 - val_loss: 0.0091
# Epoch 32/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 33/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 34/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0103 - val_loss: 0.0091
# Epoch 35/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0066 - val_loss: 0.0090
# Epoch 36/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 37/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0089 - val_loss: 0.0092
# Epoch 38/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 39/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0066 - val_loss: 0.0090
# Epoch 40/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 41/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0060 - val_loss: 0.0090
# Epoch 42/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0088 - val_loss: 0.0091
# Epoch 43/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0083 - val_loss: 0.0091
# Epoch 44/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 45/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0066 - val_loss: 0.0089
# Epoch 46/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0083 - val_loss: 0.0090
# Epoch 47/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0065 - val_loss: 0.0091
# Epoch 48/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0076 - val_loss: 0.0091
# Epoch 49/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 50/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0071 - val_loss: 0.0092
# Epoch 51/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0091 - val_loss: 0.0092
# Epoch 52/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 53/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0088 - val_loss: 0.0092
# Epoch 54/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0072 - val_loss: 0.0089
# Epoch 55/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0107 - val_loss: 0.0090
# Epoch 56/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 57/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0076 - val_loss: 0.0093
# Epoch 58/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0067 - val_loss: 0.0091
# Epoch 59/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0079 - val_loss: 0.0091
# Epoch 60/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0070 - val_loss: 0.0089
# Epoch 61/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 62/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0081 - val_loss: 0.0091
# Epoch 63/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 64/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0074 - val_loss: 0.0092
# Epoch 65/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0082 - val_loss: 0.0092
# Epoch 66/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0069 - val_loss: 0.0091
# Epoch 67/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 68/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0104 - val_loss: 0.0092
# Epoch 69/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0073 - val_loss: 0.0092
# Epoch 70/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0066 - val_loss: 0.0090
# Epoch 71/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0076 - val_loss: 0.0091
# Epoch 72/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0065 - val_loss: 0.0090
# Epoch 73/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0079 - val_loss: 0.0090
# Epoch 74/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0084 - val_loss: 0.0091
# Epoch 75/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0076 - val_loss: 0.0093
# Epoch 76/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0084 - val_loss: 0.0091
# Epoch 77/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0069 - val_loss: 0.0088
# Epoch 78/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0092 - val_loss: 0.0092
# Epoch 79/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 80/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 81/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0073 - val_loss: 0.0092
# Epoch 82/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0079 - val_loss: 0.0089
# Epoch 83/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0063 - val_loss: 0.0089
# Epoch 84/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 85/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0081 - val_loss: 0.0091
# Epoch 86/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0079 - val_loss: 0.0092
# Epoch 87/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0086 - val_loss: 0.0092
# Epoch 88/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 89/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0068 - val_loss: 0.0090
# Epoch 90/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 91/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0071 - val_loss: 0.0092
# Epoch 92/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0076 - val_loss: 0.0092
# Epoch 93/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0074 - val_loss: 0.0090
# Epoch 94/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0078 - val_loss: 0.0089
# Epoch 95/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 96/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0060 - val_loss: 0.0089
# Epoch 97/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 98/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0073 - val_loss: 0.0089
# Epoch 99/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 100/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0083 - val_loss: 0.0090
# Epoch 101/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 102/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0068 - val_loss: 0.0092
# Epoch 103/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0070 - val_loss: 0.0091
# Epoch 104/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0081 - val_loss: 0.0091
# Epoch 105/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0069 - val_loss: 0.0091
# Epoch 106/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0065 - val_loss: 0.0090
# Epoch 107/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0070 - val_loss: 0.0089
# Epoch 108/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 109/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0062 - val_loss: 0.0090
# Epoch 110/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 111/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 112/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 113/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0078 - val_loss: 0.0090
# Epoch 114/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 115/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 116/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0079 - val_loss: 0.0090
# Epoch 117/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0068 - val_loss: 0.0090
# Epoch 118/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0092 - val_loss: 0.0091
# Epoch 119/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0078 - val_loss: 0.0090
# Epoch 120/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0082 - val_loss: 0.0092
# Epoch 121/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 122/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0067 - val_loss: 0.0089
# Epoch 123/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0068 - val_loss: 0.0089
# Epoch 124/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0085 - val_loss: 0.0091
# Epoch 125/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0065 - val_loss: 0.0090
# Epoch 126/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 127/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0066 - val_loss: 0.0091
# Epoch 128/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0073 - val_loss: 0.0089
# Epoch 129/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 130/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 131/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0097 - val_loss: 0.0091
# Epoch 132/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0078 - val_loss: 0.0089
# Epoch 133/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0083 - val_loss: 0.0091
# Epoch 134/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0078 - val_loss: 0.0091
# Epoch 135/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0093 - val_loss: 0.0090
# Epoch 136/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0073 - val_loss: 0.0091
# Epoch 137/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0076 - val_loss: 0.0094
# Epoch 138/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0068 - val_loss: 0.0090
# Epoch 139/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 140/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0081 - val_loss: 0.0091
# Epoch 141/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0066 - val_loss: 0.0089
# Epoch 142/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0068 - val_loss: 0.0091
# Epoch 143/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 144/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0103 - val_loss: 0.0090
# Epoch 145/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0068 - val_loss: 0.0089
# Epoch 146/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0076 - val_loss: 0.0091
# Epoch 147/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0083 - val_loss: 0.0090
# Epoch 148/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0080 - val_loss: 0.0091
# Epoch 149/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0075 - val_loss: 0.0089
# Epoch 150/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0091 - val_loss: 0.0089
# Epoch 151/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0092 - val_loss: 0.0090
# Epoch 152/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0070 - val_loss: 0.0089
# Epoch 153/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 154/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0097 - val_loss: 0.0090
# Epoch 155/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0083 - val_loss: 0.0090
# Epoch 156/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 157/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0073 - val_loss: 0.0091
# Epoch 158/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0077 - val_loss: 0.0089
# Epoch 159/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0097 - val_loss: 0.0090
# Epoch 160/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0079 - val_loss: 0.0092
# Epoch 161/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0074 - val_loss: 0.0090
# Epoch 162/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0074 - val_loss: 0.0091
# Epoch 163/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 164/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 165/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0088 - val_loss: 0.0092
# Epoch 166/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0076 - val_loss: 0.0089
# Epoch 167/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0078 - val_loss: 0.0091
# Epoch 168/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 169/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 170/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0064 - val_loss: 0.0090
# Epoch 171/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0102 - val_loss: 0.0091
# Epoch 172/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 173/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0077 - val_loss: 0.0093
# Epoch 174/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0081 - val_loss: 0.0089
# Epoch 175/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0094 - val_loss: 0.0090
# Epoch 176/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 177/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0083 - val_loss: 0.0089
# Epoch 178/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0061 - val_loss: 0.0089
# Epoch 179/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0071 - val_loss: 0.0089
# Epoch 180/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0076 - val_loss: 0.0089
# Epoch 181/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0060 - val_loss: 0.0089
# Epoch 182/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 183/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 184/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 185/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 186/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0091 - val_loss: 0.0091
# Epoch 187/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0079 - val_loss: 0.0090
# Epoch 188/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 189/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0074 - val_loss: 0.0090
# Epoch 190/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 191/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 192/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 193/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 194/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0070 - val_loss: 0.0091
# Epoch 195/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 196/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 197/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0083 - val_loss: 0.0090
# Epoch 198/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0078 - val_loss: 0.0091
# Epoch 199/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0080 - val_loss: 0.0091
# Epoch 200/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 201/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 202/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0092 - val_loss: 0.0090
# Epoch 203/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0092 - val_loss: 0.0090
# Epoch 204/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0078 - val_loss: 0.0090
# Epoch 205/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 206/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0085 - val_loss: 0.0090
# Epoch 207/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0063 - val_loss: 0.0090
# Epoch 208/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0075 - val_loss: 0.0089
# Epoch 209/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 210/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0090 - val_loss: 0.0089
# Epoch 211/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0065 - val_loss: 0.0089
# Epoch 212/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0074 - val_loss: 0.0091
# Epoch 213/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0083 - val_loss: 0.0089
# Epoch 214/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0077 - val_loss: 0.0090
# Epoch 215/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0085 - val_loss: 0.0091
# Epoch 216/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0067 - val_loss: 0.0089
# Epoch 217/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 218/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 219/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0068 - val_loss: 0.0089
# Epoch 220/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0073 - val_loss: 0.0089
# Epoch 221/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0091 - val_loss: 0.0092
# Epoch 222/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0086 - val_loss: 0.0091
# Epoch 223/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0081 - val_loss: 0.0092
# Epoch 224/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0077 - val_loss: 0.0090
# Epoch 225/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0076 - val_loss: 0.0091
# Epoch 226/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0083 - val_loss: 0.0089
# Epoch 227/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.0064 - val_loss: 0.0089
# Epoch 228/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0090 - val_loss: 0.0090
# Epoch 229/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0074 - val_loss: 0.0090
# Epoch 230/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 231/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 232/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 233/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0066 - val_loss: 0.0090
# Epoch 234/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 235/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0111 - val_loss: 0.0091
# Epoch 236/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 237/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 238/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0083 - val_loss: 0.0091
# Epoch 239/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 240/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0082 - val_loss: 0.0090
# Epoch 241/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 242/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0068 - val_loss: 0.0090
# Epoch 243/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 244/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0084 - val_loss: 0.0091
# Epoch 245/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 246/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0068 - val_loss: 0.0091
# Epoch 247/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 248/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0073 - val_loss: 0.0091
# Epoch 249/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0089 - val_loss: 0.0090
# Epoch 250/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0080 - val_loss: 0.0093
# Epoch 251/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0083 - val_loss: 0.0091
# Epoch 252/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0070 - val_loss: 0.0091
# Epoch 253/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0091 - val_loss: 0.0090
# Epoch 254/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0093 - val_loss: 0.0090
# Epoch 255/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 256/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0090 - val_loss: 0.0090
# Epoch 257/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0066 - val_loss: 0.0090
# Epoch 258/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0106 - val_loss: 0.0090
# Epoch 259/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0068 - val_loss: 0.0090
# Epoch 260/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0054 - val_loss: 0.0089
# Epoch 261/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0069 - val_loss: 0.0090
# Epoch 262/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 263/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 264/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0065 - val_loss: 0.0089
# Epoch 265/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0078 - val_loss: 0.0090
# Epoch 266/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 267/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0075 - val_loss: 0.0091
# Epoch 268/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 269/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0066 - val_loss: 0.0091
# Epoch 270/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0085 - val_loss: 0.0091
# Epoch 271/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 272/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0076 - val_loss: 0.0091
# Epoch 273/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0066 - val_loss: 0.0091
# Epoch 274/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 275/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0063 - val_loss: 0.0089
# Epoch 276/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 277/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0074 - val_loss: 0.0090
# Epoch 278/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0098 - val_loss: 0.0093
# Epoch 279/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0078 - val_loss: 0.0090
# Epoch 280/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0102 - val_loss: 0.0091
# Epoch 281/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 282/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 283/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0077 - val_loss: 0.0090
# Epoch 284/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0067 - val_loss: 0.0089
# Epoch 285/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0090 - val_loss: 0.0091
# Epoch 286/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0086 - val_loss: 0.0090
# Epoch 287/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 288/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0061 - val_loss: 0.0089
# Epoch 289/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0084 - val_loss: 0.0090
# Epoch 290/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0055 - val_loss: 0.0089
# Epoch 291/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0066 - val_loss: 0.0089
# Epoch 292/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0084 - val_loss: 0.0091
# Epoch 293/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0075 - val_loss: 0.0089
# Epoch 294/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0098 - val_loss: 0.0091
# Epoch 295/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0072 - val_loss: 0.0089
# Epoch 296/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0074 - val_loss: 0.0091
# Epoch 297/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0067 - val_loss: 0.0089
# Epoch 298/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0084 - val_loss: 0.0092
# Epoch 299/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 300/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0084 - val_loss: 0.0090
# Epoch 301/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 302/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0063 - val_loss: 0.0090
# Epoch 303/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0071 - val_loss: 0.0089
# Epoch 304/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0075 - val_loss: 0.0089
# Epoch 305/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 306/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 307/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 308/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0065 - val_loss: 0.0089
# Epoch 309/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0078 - val_loss: 0.0091
# Epoch 310/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0068 - val_loss: 0.0091
# Epoch 311/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0090 - val_loss: 0.0091
# Epoch 312/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 313/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 314/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 315/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0070 - val_loss: 0.0091
# Epoch 316/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0066 - val_loss: 0.0090
# Epoch 317/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0064 - val_loss: 0.0090
# Epoch 318/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 319/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 320/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0060 - val_loss: 0.0090
# Epoch 321/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 322/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0068 - val_loss: 0.0090
# Epoch 323/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0068 - val_loss: 0.0091
# Epoch 324/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 325/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 326/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 327/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 328/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 329/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 330/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0069 - val_loss: 0.0090
# Epoch 331/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0083 - val_loss: 0.0090
# Epoch 332/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0075 - val_loss: 0.0089
# Epoch 333/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 334/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0064 - val_loss: 0.0089
# Epoch 335/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 336/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 337/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 338/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0064 - val_loss: 0.0091
# Epoch 339/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0069 - val_loss: 0.0090
# Epoch 340/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0078 - val_loss: 0.0090
# Epoch 341/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0074 - val_loss: 0.0090
# Epoch 342/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0061 - val_loss: 0.0090
# Epoch 343/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 344/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0079 - val_loss: 0.0090
# Epoch 345/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 346/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 347/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0066 - val_loss: 0.0090
# Epoch 348/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0081 - val_loss: 0.0089
# Epoch 349/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 350/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 351/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 352/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0091 - val_loss: 0.0090
# Epoch 353/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0074 - val_loss: 0.0091
# Epoch 354/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0074 - val_loss: 0.0090
# Epoch 355/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0062 - val_loss: 0.0090
# Epoch 356/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 357/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 358/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0065 - val_loss: 0.0091
# Epoch 359/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 360/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0069 - val_loss: 0.0091
# Epoch 361/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0079 - val_loss: 0.0089
# Epoch 362/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0073 - val_loss: 0.0091
# Epoch 363/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 364/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0083 - val_loss: 0.0092
# Epoch 365/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0082 - val_loss: 0.0090
# Epoch 366/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 367/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0084 - val_loss: 0.0090
# Epoch 368/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0081 - val_loss: 0.0092
# Epoch 369/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 370/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0078 - val_loss: 0.0090
# Epoch 371/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0077 - val_loss: 0.0092
# Epoch 372/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0065 - val_loss: 0.0091
# Epoch 373/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0090 - val_loss: 0.0090
# Epoch 374/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0075 - val_loss: 0.0093
# Epoch 375/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0078 - val_loss: 0.0091
# Epoch 376/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0079 - val_loss: 0.0092
# Epoch 377/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0086 - val_loss: 0.0090
# Epoch 378/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0068 - val_loss: 0.0091
# Epoch 379/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 380/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0092 - val_loss: 0.0091
# Epoch 381/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0086 - val_loss: 0.0090
# Epoch 382/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 383/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0077 - val_loss: 0.0089
# Epoch 384/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0089 - val_loss: 0.0090
# Epoch 385/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0082 - val_loss: 0.0093
# Epoch 386/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 387/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 388/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0093 - val_loss: 0.0090
# Epoch 389/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 390/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0083 - val_loss: 0.0089
# Epoch 391/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 392/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0077 - val_loss: 0.0092
# Epoch 393/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 394/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 395/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0077 - val_loss: 0.0090
# Epoch 396/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 397/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 398/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0091 - val_loss: 0.0092
# Epoch 399/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 400/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0079 - val_loss: 0.0091
# Epoch 401/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0073 - val_loss: 0.0091
# Epoch 402/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0084 - val_loss: 0.0091
# Epoch 403/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0091 - val_loss: 0.0090
# Epoch 404/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0078 - val_loss: 0.0091
# Epoch 405/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0091 - val_loss: 0.0092
# Epoch 406/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 407/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0066 - val_loss: 0.0089
# Epoch 408/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0081 - val_loss: 0.0091
# Epoch 409/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0084 - val_loss: 0.0090
# Epoch 451/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 452/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0075 - val_loss: 0.0091
# Epoch 453/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 454/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 455/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0078 - val_loss: 0.0091
# Epoch 456/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0065 - val_loss: 0.0092
# Epoch 457/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0069 - val_loss: 0.0091
# Epoch 458/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 84s 292ms/step - loss: 0.0075 - val_loss: 0.0091
# Epoch 459/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 460/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0073 - val_loss: 0.0089
# Epoch 461/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 462/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0063 - val_loss: 0.0091
# Epoch 463/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0092 - val_loss: 0.0091
# Epoch 464/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 465/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0057 - val_loss: 0.0090
# Epoch 466/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0070 - val_loss: 0.0092
# Epoch 467/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0072 - val_loss: 0.0089
# Epoch 468/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 469/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 470/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0063 - val_loss: 0.0090
# Epoch 471/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0078 - val_loss: 0.0090
# Epoch 472/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 473/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 474/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 475/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0097 - val_loss: 0.0091
# Epoch 476/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0082 - val_loss: 0.0092
# Epoch 477/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0091 - val_loss: 0.0092
# Epoch 478/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 479/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0074 - val_loss: 0.0091
# Epoch 480/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 481/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0081 - val_loss: 0.0091
# Epoch 482/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0080 - val_loss: 0.0091
# Epoch 483/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0070 - val_loss: 0.0089
# Epoch 484/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 485/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0080 - val_loss: 0.0092
# Epoch 486/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 487/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0080 - val_loss: 0.0091
# Epoch 488/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 489/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 490/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0088 - val_loss: 0.0091
# Epoch 491/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0082 - val_loss: 0.0090
# Epoch 492/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0098 - val_loss: 0.0092
# Epoch 493/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0068 - val_loss: 0.0090
# Epoch 494/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0093 - val_loss: 0.0091
# Epoch 495/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0077 - val_loss: 0.0092
# Epoch 496/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0085 - val_loss: 0.0091
# Epoch 497/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 498/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0078 - val_loss: 0.0090
# Epoch 499/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0083 - val_loss: 0.0091
# Epoch 500/500
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0083 - val_loss: 0.0090

# %%
# Evaluate the model
evaluate_model(model, scaler, X_train, y_train, X_test, y_test)
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step
# RMSE:  1159.3020
# MAPE:  99.94
# MAE:  757.2377
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RMSE:  1279.9966
# MAPE:  99.92
# MAE:  857.0465

# %% [markdown]
# ### Insights
#
# #### High Error Rates (MAPE):
#
# - Both training and testing MAPE are near 100%, which is extremely high. This indicates that the model struggles to accurately capture the proportional changes in the time series.
# - The model fails to generalize well to unseen data, suggesting issues with either:
#     - Model complexity (insufficient learning capacity for this dataset).
#     - Data preprocessing or the inherent nature of the data.
#
# #### Overfitting or Underfitting:
#
# - The difference between training and testing metrics is small, indicating that the model may be underfitting the data rather than overfitting.
# - This might occur because the model complexity (50 units per layer) is not sufficient to learn intricate patterns in the sales data.
#
# #### MAE and RMSE Insights:
#
# - The RMSE values **(1159.31 for training, 1280.00 for testing)** show that the error magnitude is substantial in both cases.
# - The slightly higher testing RMSE suggests a marginal degradation in performance on unseen data, a typical sign of limited model capacity.
#
# #### Effect of Hyperparameters:
#
# - Despite varying epochs and batch sizes, the high MAPE persists. This suggests that neither increasing training duration nor tuning batch sizes effectively improves the model's performance.
